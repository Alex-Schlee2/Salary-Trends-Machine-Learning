# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Dataset 3- Exploratory Data Analysis.csv', index_col=0)

# %%
df.head()
# Out:
#    Salary_Average in $                                          Job_title  \
# 0             23328.63  Apprentice Radiotherapy Engineer (Clinical Tec...
# 1             62230.00                          Machine Learning Engineer
# 2             38100.00         Deep Learning Engineer (Signal Processing)
# 3             59055.00  Senior Machine Learning Engineer / Machine Lea...
# 4             73025.00                           Senior Software Engineer
#
#                                         Company_name     Location  \
# 0  University Hospital Southampton NHS Foundation...  Southampton
# 1                                     Cyberlens Ltd.       London
# 2                                      Drone Defence      Retford
# 3                          Nucleome Therapeutics Ltd       Oxford
# 4                                           WCKD RZR       London
#
#                                      Job_Description  R_Skills  Java_Skills  \
# ...

# %% [markdown]
# ### get dummy data

# %%
df.columns
# Out:
# Index(['Salary_Average in $', 'Job_title', 'Company_name', 'Location',
#        'Job_Description', 'R_Skills', 'Java_Skills', 'SQL_Skills',
#        'Spark_Skills', 'Matlab_Skills', 'Tensorflow_Skills', 'NLP_Skills',
#        'Python_Skills', 'C++_Skills'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207 entries, 0 to 210
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Salary_Average in $  207 non-null    float64
#  1   Job_title            207 non-null    object
#  2   Company_name         207 non-null    object
#  3   Location             207 non-null    object
#  4   Job_Description      207 non-null    object
#  5   R_Skills             207 non-null    int64
#  6   Java_Skills          207 non-null    int64
#  7   SQL_Skills           207 non-null    int64
#  8   Spark_Skills         207 non-null    int64
#  9   Matlab_Skills        207 non-null    int64
#  10  Tensorflow_Skills    207 non-null    int64
#  11  NLP_Skills           207 non-null    int64
#  12  Python_Skills        207 non-null    int64
#  13  C++_Skills           207 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 24.3+ KB

# %%
df_relevant_columns=df[['Salary_Average in $',  'Python_Skills', 'Location', 'Company_name',
                       'Java_Skills', 'SQL_Skills', 'Matlab_Skills','Tensorflow_Skills', 'NLP_Skills', 'C++_Skills', 'R_Skills',
                       'Spark_Skills']]

# %%
df_dummies=pd.get_dummies(df_relevant_columns, drop_first=True)

# %%
df_dummies
# Out:
#      Salary_Average in $  Python_Skills  Java_Skills  SQL_Skills  \
# 0               23328.63              0            0           0
# 1               62230.00              1            0           0
# 2               38100.00              1            0           0
# 3               59055.00              1            0           0
# 4               73025.00              0            1           0
# ..                   ...            ...          ...         ...
# 206             63500.00              1            1           0
# 207             76200.00              0            0           1
# 208             69850.00              1            1           0
# 209             85725.00              0            0           0
# 210             79375.00              1            0           0
#
#      Matlab_Skills  Tensorflow_Skills  NLP_Skills  C++_Skills  R_Skills  \
# 0                0                  0           0           0         0
# ...

# %%
df_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207 entries, 0 to 210
# Columns: 144 entries, Salary_Average in $ to Company_name_re&m
# dtypes: float64(1), int64(9), uint8(134)
# memory usage: 44.9 KB

# %% [markdown]
# ### train test split

# %%
from sklearn.model_selection import train_test_split

# %%
#test columns
X=df_dummies.drop('Salary_Average in $', axis=1)
y=df['Salary_Average in $'].values

#train set, test set
#test_size=0.2 (= 80% in train set, 20% in test set)
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.3)

# %%
df['Salary_Average in $']
# Out:
# 0      23328.63
# 1      62230.00
# 2      38100.00
# 3      59055.00
# 4      73025.00
#          ...
# 206    63500.00
# 207    76200.00
# 208    69850.00
# 209    85725.00
# 210    79375.00
# Name: Salary_Average in $, Length: 207, dtype: float64

# %% [markdown]
# ## Feature Evaluation

# %%
X_sm= X = sm.add_constant(X)
model=sm.OLS(y,X_sm)
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     1.849
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):            0.00117
# Time:                        19:44:59   Log-Likelihood:                -2366.5
# No. Observations:                 207   AIC:                             4959.
# Df Residuals:                      94   BIC:                             5336.
# Df Model:                         112
# Covariance Type:            nonrobust
# ...
#                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ...
